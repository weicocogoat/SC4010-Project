# %%
import pandas as pd
import matplotlib.pyplot as plt

from math import factorial
import numpy as np
import scipy.io
import scipy.signal
import sys

# %%
df = pd.read_csv('F0000CH2.CSV')
df_timing = pd.read_csv('F0000CH1.CSV')

# %%
df_timing
# Out:
#            Unnamed: 0           Unnamed: 1  Unnamed: 2      Time  Voltage
# 0       Record Length         2.500000e+03         NaN  0.000196      0.2  \
# 1     Sample Interval         2.000000e-07         NaN  0.000196      0.2
# 2       Trigger Point  -9.800000000000e+02         NaN  0.000196     -0.4
# 3                 NaN                  NaN         NaN  0.000197      0.2
# 4                 NaN                  NaN         NaN  0.000197      0.4
# ...               ...                  ...         ...       ...      ...
# 2495              NaN                  NaN         NaN  0.000695      0.2
# 2496              NaN                  NaN         NaN  0.000695      0.2
# 2497              NaN                  NaN         NaN  0.000695      0.2
# 2498              NaN                  NaN         NaN  0.000696      0.0
# 2499              NaN                  NaN         NaN  0.000696      0.0
#
#       Unnamed: 5
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2495         NaN
# 2496         NaN
# 2497         NaN
# 2498         NaN
# 2499         NaN
#
# [2500 rows x 6 columns]

# %%
df_clean = df[['Time', 'Voltage']]
df_clean
# Out:
#           Time  Voltage
# 0     0.000196   4.2120
# 1     0.000196   4.2200
# 2     0.000196   4.2128
# 3     0.000197   4.2128
# 4     0.000197   4.2192
# ...        ...      ...
# 2495  0.000695   4.2184
# 2496  0.000695   4.2232
# 2497  0.000695   4.2248
# 2498  0.000696   4.2216
# 2499  0.000696   4.2248
#
# [2500 rows x 2 columns]

# %%
df_clean.plot(x= 'Time', y = 'Voltage')
# Out:
# <Axes: xlabel='Time'>

# %%
df_filtered = scipy.signal.savgol_filter(df_clean['Voltage'], 35, 10)

# %%
df_filtered
# Out:
# array([4.21521101, 4.2114248 , 4.21393765, ..., 4.22322394, 4.22369645,
#        4.22419662])

# %%
plt.plot(df_filtered)

# %%
df_2 = df_clean
df_2
# Out:
#           Time   Voltage
# 0     0.000196  4.215068
# 1     0.000196  4.211795
# 2     0.000196  4.213901
# 3     0.000197  4.218643
# 4     0.000197  4.223328
# ...        ...       ...
# 2495  0.000695  4.219970
# 2496  0.000695  4.221904
# 2497  0.000695  4.223227
# 2498  0.000696  4.223660
# 2499  0.000696  4.224211
#
# [2500 rows x 2 columns]

# %%
tsint = df_2.interpolate(method='cubic')

# %%
tsint

# %%
plt.plot(tsint['Voltage'])
#plt.plot(df_filtered)

# %%
plt.figure(figsize=(30,10))
plt.plot(df_filtered)

# %%
plt.figure(figsize=(30,10))
plt.plot(df_timing["Voltage"])
