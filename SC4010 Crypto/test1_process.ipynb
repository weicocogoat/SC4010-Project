# %%
import pandas as pd
import matplotlib.pyplot as plt

from math import factorial
import numpy as np
import scipy.io
import scipy.signal
import sys

# %%
df = pd.read_csv('test1.csv')
df
# Out:
#          X   CH1  CH2  Start  Increment  Unnamed: 5
# 0        0  4.12  0.0    NaN        NaN         NaN
# 1        1  4.13  0.6    NaN        NaN         NaN
# 2        2  4.14  0.0    NaN        NaN         NaN
# 3        3  4.12  0.6    NaN        NaN         NaN
# 4        4  4.12  0.0    NaN        NaN         NaN
# ...    ...   ...  ...    ...        ...         ...
# 1195  1195  4.13  0.6    NaN        NaN         NaN
# 1196  1196  4.13  0.0    NaN        NaN         NaN
# 1197  1197  4.12  0.6    NaN        NaN         NaN
# 1198  1198  4.14  0.0    NaN        NaN         NaN
# 1199  1199  4.12  0.6    NaN        NaN         NaN
#
# [1200 rows x 6 columns]

# %%
df_CH1= df[['X', 'CH1']]
df_CH2 = df [['X', 'CH2']]

# %%
df_filtered = scipy.signal.savgol_filter(df_trace['CH1'], 35, 10)
plt.figure(figsize=(30,10))
plt.plot(df_filtered)

# %%
plt.figure(figsize=(30,10))
plt.plot(df_CH2['CH2'])
